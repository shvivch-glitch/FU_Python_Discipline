# %% [markdown]
# # ЗАДАНИЕ 3. Условный оператор.

# %%
# №1
a = float(input("Введите a: "))
x = float(input("Введите x: "))

if x > 0:
    y = a * x**2 + 1
else:
    y = a * x - 1

print(f"y = {y}")

# %%
# №2
a = float(input("Введите a: "))
x = float(input("Введите x: "))

if x >= 1:
    y = a * x + 1
else:
    y = x**2 - 1

print(f"y = {y}")

# %%
# №3
a = float(input("Введите a: "))
x = float(input("Введите x: "))

if x < 0:
    y = 3 * a**2
else:
    y = 4 * a * x - 1

print(f"y = {y}")

# %%
# №4
a = float(input("Введите a: "))
x = float(input("Введите x: "))

if x > 4:
    y = 2 * a**2
else:
    y = 3 * x - 1

print(f"y = {y}")

# %%
# №5
a = float(input("Введите a: "))
x = float(input("Введите x: "))

if x > 2:
    y = 2 * a * x - 2
else:
    y = 3 * a**2 - 2 * x

print(f"y = {y}")

# %%
# №6
a = float(input("Введите a: "))
x = float(input("Введите x: "))

if x > 1:
    y = 2 * a * x**2 - 1
else:
    y = x

print(f"y = {y}")

# %%
# №7
a = float(input("Введите a: "))
x = float(input("Введите x: "))

if x > 2:
    y = x**2
else:
    y = 2 * a - 1

print(f"y = {y}")

# %%
# №8
import math
x = float(input("Введите x: "))

if x > 2:
    y = math.cos(2 * x - 1)
else:
    y = math.sin(3 * x + 1)

print(f"y = {y}")

# %%
# №9
x = float(input("Введите x: "))

if x > 2:
    y = 2 * x**3 - 2 * x - 1
else:
    y = 3 * x**2 - 2 * x + 1

print(f"y = {y}")

# %%
# №10
a = float(input("Введите a: "))
x = float(input("Введите x: "))

if x > 1:
    y = 2 * a * x**2 - 1
else:
    y = 1 / a

print(f"y = {y}")

# %%
# №11
import math
a = float(input("Введите a: "))
x = float(input("Введите x: "))

if x >= 0:
    y = a * math.sqrt(x) + 1
else:
    y = a * x - 1

print(f"y = {y}")

# %%
# №12
import math
a = float(input("Введите a: "))
x = float(input("Введите x: "))

if x >= 0:
    y = math.sqrt(x) + a
else:
    y = a / x - 1

print(f"y = {y}")

# %%
# №13
a = float(input("Введите a: "))
x = float(input("Введите x: "))

if x > 0:
    y = 1 / x + a
else:
    y = x**2 - 1

print(f"y = {y}")

# %%
# №14
import math
x = float(input("Введите x: "))

if x > math.pi / 2:
    y = math.cos(x)
else:
    y = math.sin(x)

print(f"y = {y}")

# %%
# №15
import math
x = float(input("Введите x: "))

if x > 2:
    y = math.sqrt(x - 2)
else:
    y = (x - 2)**2 + 1

print(f"y = {y}")
